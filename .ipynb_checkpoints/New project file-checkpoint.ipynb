# %% [markdown]
# <h1>Investigating Aggregate Factors Associated with Car Insurance Prices</h1>

# %% [markdown]
# Group members:
# Karina Li,
# Daisy Liu,
# Xinyu Li,
# Catherine Yang

# %% [markdown]
# <h1>Intro</h1>

# %% [markdown]
# The United States holds the distinction of being the largest insurance market globally,
# significantly outpacing other countries. In 2022, the U.S. insurance market recorded the
# highest value of life and non-life direct premiums, more than four times that of the
# second-ranked Chinese market, according to data from Statista. Recently, the rising cost
# of automobile insurance in the U.S. has been attributed to increases in the frequency and
# severity of auto accidents, compounded by factors such as distracted driving and medical
# cost inflation. This paper seeks to explore how aggregate factors, such as the prevalence
# of bad drivers, frequency of accidents, and incidents of theft, correlate with higher
# insurance costs. The insights gained from this research could help mitigate price
# discrimination, protect consumer rights, and promote a healthier insurance industry.

# %% [markdown]
# **First Dataset:**
# The primary dataset used in this research is sourced from the FiveThirtyEight’s bad
# driver’s dataset available on Kaggle. This dataset compiles information from the National
# Highway Traffic Safety Administration (NHTSA) and the National Association of
# Insurance Commissioners (NAIC). It specifically includes data on the number of
# accidents attributed to alcohol-impaired driving and speeding, alongside car insurance
# premiums and the financial losses incurred by insurance companies due to collisions.
# This data will allow us to analyze the direct impact of driver behavior on insurance costs.

# %% [markdown]
# **Second Dataset:**
# Further, we utilize a comprehensive accident dataset from Kaggle, which covers 49
# states of the USA with approximately 7.7 million records. This dataset details each
# accident&#39;s severity on a scale from 1 to 4, where 1 signifies minimal traffic impact. It also
# provides geographical coordinates for accidents, the local time when they occurred, and
# the extent of the road affected. This dataset aids in understanding the geographic
# distribution and timing of accidents, crucial for assessing risk factors associated with
# higher insurance premiums.

# %% [markdown]
# **Third Dataset:**
# Additionally, we incorporate crime statistics from another Kaggle dataset, which includes
# reports from the U.S. Department of Justice and the Federal Bureau of Investigation
# covering all 49 states. This dataset categorizes crimes into property and violent crimes
# and includes variables such as state, year, population, and specific crime counts such as
# burglary, murder, and motor vehicle-related crimes. By examining the relationship
# between crime rates and insurance costs, we can identify broader societal factors
# influencing insurance pricing strategies.

# %% [markdown]
# Through statistical analysis and regression modeling, this study will provide valuable
# insights into how different risk factors contribute to insurance costs. The findings are
# expected not only to advance academic understanding but also to inform practical
# strategies for pricing insurance products, ultimately fostering a more equitable and
# effective insurance market.

# %% [markdown]
# **RESEARCH QUESTION**
#
# Our primary research question is this: **To what extend can the identified aggregate factors predict insurance prices?**
#
# Although car insurance costs vary between individuals based on their attributes (eg. age, experience, etc.) to what extent are average car insurance costs correlate with more general statistics (eg. the amount of bad driving behaviors in a state or the amount of car thefts that goes on in a state)?
#
# Further question for investigation:
# What are the different impacts of independent variables on full insurance coverage price / minimum insurance coverage price?
#
# Our hypothesis is that the minimum insurance coverage price may be less influenced by the independent variables because they do not have to provide coverage for more significant losses, so their prices won't be as influenced by factors such as the rate of fatal collisions and the rate of car theft. We will verify this hypothesis with regression

# %% [markdown]
# **OUTLINE OF PROJECT CONTENT**
#
# - Visualization of correlation between independent factors and insurance price and average insurance prices in each US state
#
# - Frequency and Severity Analysis
#
# - Regression analysis
#
# - Conclusion

# %% [markdown]
# <h1>Loading Packages & Datasets</h1>

# %%
! pip install fiona geopandas xgboost gensim pyLDAvis descartes mapclassify opendatasets
# Out:
# Collecting fiona
#   Using cached fiona-1.9.6-cp310-cp310-manylinux2014_x86_64.whl (15.7 MB)
# Collecting geopandas
#   Using cached geopandas-0.14.3-py3-none-any.whl (1.1 MB)
# Collecting xgboost
#   Using cached xgboost-2.0.3-py3-none-manylinux2014_x86_64.whl (297.1 MB)
# Collecting gensim
#   Using cached gensim-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
# Collecting pyLDAvis
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# Collecting descartes
#   Using cached descartes-1.1.0-py3-none-any.whl (5.8 kB)
# Collecting mapclassify
#   Using cached mapclassify-2.6.1-py3-none-any.whl (38 kB)
# Collecting opendatasets
#   Using cached opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona) (22.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona) (1.16.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.10/site-packages (from fiona) (8.1.3)
# Collecting click-plugins>=1.0
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from fiona) (2022.12.7)
# Collecting pyproj>=3.3.0
#   Using cached pyproj-3.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Collecting shapely>=1.8.0
#   Using cached shapely-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from geopandas) (23.0)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from geopandas) (1.5.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from xgboost) (1.23.5)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-7.0.4-py3-none-any.whl (61 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from pyLDAvis) (67.6.1)
# Collecting funcy
#   Using cached funcy-2.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from pyLDAvis) (3.1.2)
# Collecting pandas>=1.4.0
#   Using cached pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
# Requirement already satisfied: numexpr in /opt/conda/lib/python3.10/site-packages (from pyLDAvis) (2.8.3)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from pyLDAvis) (1.2.0)
# Collecting numpy
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from descartes) (3.6.3)
# Requirement already satisfied: networkx>=2.7 in /opt/conda/lib/python3.10/site-packages (from mapclassify) (2.8.8)
# Collecting kaggle
#   Using cached kaggle-1.6.12-py3-none-any.whl
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.1.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open>=1.8.1->gensim) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->pyLDAvis) (2.1.2)
# Collecting certifi
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (1.26.14)
# Collecting python-slugify
#   Using cached python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (2.28.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Collecting text-unidecode>=1.3
#   Using cached text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (3.4)
# Installing collected packages: text-unidecode, funcy, smart-open, python-slugify, numpy, cligj, click-plugins, certifi, shapely, pyproj, pandas, fiona, xgboost, kaggle, geopandas, gensim, pyLDAvis, opendatasets, mapclassify, descartes
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.12.7
#     Uninstalling certifi-2022.12.7:
#       Successfully uninstalled certifi-2022.12.7
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sagemath-standard 9.7 requires fpylll<=0.5.7,>=0.5.6, but you have fpylll 0.5.9 which is incompatible.
# sagemath-standard 9.7 requires ipywidgets>=7.5.1, but you have ipywidgets 7.4.2 which is incompatible.
# sagemath-standard 9.7 requires ptyprocess==0.5.1, but you have ptyprocess 0.7.0 which is incompatible.
# sagemath-standard 9.7 requires rpy2<3.4,>=3.3, but you have rpy2 3.5.7 which is incompatible.
# sagemath-standard 9.7 requires sphinx<4.5,>=4.3, but you have sphinx 4.5.0 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.26.4 which is incompatible.
# ipympl 0.9.2 requires ipywidgets<9,>=7.6.0, but you have ipywidgets 7.4.2 which is incompatible.
# Successfully installed certifi-2024.2.2 click-plugins-1.1.1 cligj-0.7.2 descartes-1.1.0 fiona-1.9.6 funcy-2.0 gensim-4.3.2 geopandas-0.14.3 kaggle-1.6.12 mapclassify-2.6.1 numpy-1.26.4 opendatasets-0.1.22 pandas-2.2.2 pyLDAvis-3.4.1 pyproj-3.6.1 python-slugify-8.0.4 shapely-2.0.4 smart-open-7.0.4 text-unidecode-1.3 xgboost-2.0.3

# %%
! pip install geopandas opendatasets
# Out:
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.10/site-packages (0.14.3)
# Requirement already satisfied: opendatasets in /opt/conda/lib/python3.10/site-packages (0.1.22)
# Requirement already satisfied: pandas>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from geopandas) (23.0)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.10/site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: kaggle in /opt/conda/lib/python3.10/site-packages (from opendatasets) (1.6.12)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (22.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2022.7.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (2.28.2)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: urllib3 in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (1.26.14)
# Requirement already satisfied: python-slugify in /opt/conda/lib/python3.10/site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/conda/lib/python3.10/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->kaggle->opendatasets) (2.1.1)

# %%
! pip install folium requests
# Out:
# Collecting folium
#   Using cached folium-0.16.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (2.28.2)
# Collecting branca>=0.6.0
#   Using cached branca-0.7.1-py3-none-any.whl (25 kB)
# Collecting xyzservices
#   Using cached xyzservices-2024.4.0-py3-none-any.whl (81 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from folium) (1.26.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.2)
# Installing collected packages: xyzservices, branca, folium
# Successfully installed branca-0.7.1 folium-0.16.0 xyzservices-2024.4.0

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import folium
from shapely.geometry import Point
import requests
# %matplotlib inline

import numpy as np
import opendatasets as od
from sklearn import linear_model
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#set seed
np.random.seed(123)

# %%
#load datasets

bad_drivers = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/bad-drivers.csv").set_index("State")
#bad drivers by state dataset

insurance_cost = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/auto_insurance_cost.csv").set_index("state")
#insurance cost by state dataset

state_crime = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/state_crime.csv")
#Crimes by state - includes a column for car theft

registered_veh = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/Registered_Vehicle.csv")
registered_veh.columns = ['State', '2020', '2015', '%change'] #change col names
registered_veh = registered_veh.drop(['2015', '%change'], axis=1) # keep only important rows
registered_veh['2020'] = registered_veh['2020'].str.replace(',', '').astype(int) # change datatype to int
# Number of registered vehicle in US by state in 2020

## read filtered car accidents datasets, included severity and other accident factors 
## accidents happened only in 2020
us_acc_2020 = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/Filtered_US_Accidents.csv")

state_abb = pd.read_csv("https://raw.githubusercontent.com/mish-salt/323-Group-Project/main/US_states_abb.csv")
state_abb.columns = ['State_full', 'State'] # add col names

# %%
# #The dataset for car accidents is too large - here we import it directly from Kaggle
accident_data = 'https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents'
od.download(accident_data) #download dataset file

#load in dataset
us_accidents = pd.read_csv('us-accidents/US_Accidents_March23.csv', usecols = ["State", "Severity", "Start_Time"]) #The dataset is too large - select only the variables of interest
# Out:
# Skipping, found downloaded files in "./us-accidents" (use force=True to force download)

# %% [markdown]
# <h1>Viewing Datasets</h1>

# %%
bad_drivers.head()
# Out:
#             Number of drivers involved in fatal collisions per billion miles  \
# State
# Alabama                                                  18.8
# Alaska                                                   18.1
# Arizona                                                  18.6
# Arkansas                                                 22.4
# California                                               12.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# State
# Alabama                                                    39
# Alaska                                                     41
# Arizona                                                    35
# Arkansas                                                   18
# California                                                 35
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# State
# Alabama                                                    30
# Alaska                                                     25
# Arizona                                                    28
# Arkansas                                                   26
# California                                                 28
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted  \
# State
# Alabama                                                    96
# Alaska                                                     90
# Arizona                                                    84
# Arkansas                                                   94
# California                                                 91
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents  \
# State
# Alabama                                                    80
# Alaska                                                     94
# Arizona                                                    96
# Arkansas                                                   95
# California                                                 89
#
#             Car Insurance Premiums ($)  \
# State
# Alabama                         784.55
# Alaska                         1053.48
# Arizona                         899.47
# Arkansas                        827.34
# California                      878.41
#
#             Losses incurred by insurance companies for collisions per insured driver ($)
# State
# Alabama                                                145.08
# Alaska                                                 133.93
# Arizona                                                110.35
# Arkansas                                               142.39
# California                                             165.63

# %%
insurance_cost.head()
# Out:
#              rank  full_coverage  minimum_coverage  difference
# state
# Michigan        1           8723              5282        3441
# Rhode Island    2           3847              1589        2258
# Louisiana       3           3525              1329        2196
# Kentucky        4           3418              1338        2079
# Florida         5           3370              2565         805

# %%
state_crime.head()
# Out:
#      State  Year  Data.Population  Data.Rates.Property.All  \
# 0  Alabama  1960          3266740                   1035.4
# 1  Alabama  1961          3302000                    985.5
# 2  Alabama  1962          3358000                   1067.0
# 3  Alabama  1963          3347000                   1150.9
# 4  Alabama  1964          3407000                   1358.7
#
#    Data.Rates.Property.Burglary  Data.Rates.Property.Larceny  \
# 0                         355.9                        592.1
# 1                         339.3                        569.4
# 2                         349.1                        634.5
# 3                         376.9                        683.4
# 4                         466.6                        784.1
#
#    Data.Rates.Property.Motor  Data.Rates.Violent.All  \
# 0                       87.3                   186.6
# 1                       76.8                   168.5
# 2                       83.4                   157.3
# 3                       90.6                   182.7
# 4                      108.0                   213.1
#
#    Data.Rates.Violent.Assault  Data.Rates.Violent.Murder  ...  \
# 0                       138.1                       12.4  ...
# 1                       128.9                       12.9  ...
# 2                       119.0                        9.4  ...
# 3                       142.1                       10.2  ...
# 4                       163.0                        9.3  ...
#
#    Data.Rates.Violent.Robbery  Data.Totals.Property.All  \
# 0                        27.5                     33823
# 1                        19.1                     32541
# 2                        22.5                     35829
# 3                        24.7                     38521
# 4                        29.1                     46290
#
#    Data.Totals.Property.Burglary  Data.Totals.Property.Larceny  \
# 0                          11626                         19344
# 1                          11205                         18801
# 2                          11722                         21306
# 3                          12614                         22874
# 4                          15898                         26713
#
#    Data.Totals.Property.Motor  Data.Totals.Violent.All  \
# 0                        2853                     6097
# 1                        2535                     5564
# 2                        2801                     5283
# 3                        3033                     6115
# 4                        3679                     7260
#
#    Data.Totals.Violent.Assault  Data.Totals.Violent.Murder  \
# 0                         4512                         406
# 1                         4255                         427
# 2                         3995                         316
# 3                         4755                         340
# 4                         5555                         316
#
#    Data.Totals.Violent.Rape  Data.Totals.Violent.Robbery
# 0                       281                          898
# 1                       252                          630
# 2                       218                          754
# 3                       192                          828
# 4                       397                          992
#
# [5 rows x 21 columns]

# %%
us_accidents.head()
# Out:
#    Severity           Start_Time State
# 0         3  2016-02-08 05:46:00    OH
# 1         2  2016-02-08 06:07:59    OH
# 2         2  2016-02-08 06:49:27    OH
# 3         3  2016-02-08 07:23:34    OH
# 4         2  2016-02-08 07:39:07    OH

# %%
#filtering accidents data from year 2020
us_accidents["Start_Time"] = us_accidents["Start_Time"].astype(str)

us_acc_2020 = us_accidents.loc[us_accidents["Start_Time"].str.contains("2020")]

# %%
us_acc_2020.head()
# Out:
#          Severity           Start_Time State
# 1179737         2  2020-12-28 05:55:31    NJ
# 1198210         3  2020-12-31 22:57:02    IL
# 1198211         3  2020-12-31 22:03:27    IL
# 1198212         3  2020-12-31 22:58:36    IL
# 1198349         2  2020-12-31 23:32:07    CO

# %% [markdown]
# <h1>Data Wrangling</h1>

# %% [markdown]
# For visualizing the correlation between these variables & insurance prices

# %%
#merging bad driver data with insurance data
df1 = pd.merge(insurance_cost, bad_drivers, left_on = "state", right_index = True, how = "right")
#clean the crime dataset, use only obeservations from 2019, the closest time to 2020 in the dataset
crime_data = state_crime.loc[state_crime.Year == 2019].loc[:, ["Data.Rates.Property.Motor", "State"]]


#continue to merge it with the rate of stolen cars from the crime dataset


df2 = pd.merge(df1, crime_data, left_on = "state", right_on = "State", how = "right").set_index("State")





plotting_data = df2.rename(columns = {"Data.Rates.Property.Motor":"stolen_cars_per_100k"}).dropna() #the variable refers to the number of stolen cars per 100,000 population

plotting_data.head()
# Out:
#                  state rank  full_coverage  minimum_coverage  difference  \
# State
# Alabama        Alabama   31         2078.0             736.0      1342.0
# Alaska          Alaska   45         1502.0             485.0      1016.0
# Arizona        Arizona   11         2699.0             980.0      1719.0
# Arkansas      Arkansas   24         2213.0             677.0      1536.0
# California  California   39         1804.0             574.0      1230.0
#
#             Number of drivers involved in fatal collisions per billion miles  \
# State
# Alabama                                                  18.8
# Alaska                                                   18.1
# Arizona                                                  18.6
# Arkansas                                                 22.4
# California                                               12.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# State
# Alabama                                                  39.0
# Alaska                                                   41.0
# Arizona                                                  35.0
# Arkansas                                                 18.0
# California                                               35.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# State
# Alabama                                                  30.0
# Alaska                                                   25.0
# Arizona                                                  28.0
# Arkansas                                                 26.0
# California                                               28.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted  \
# State
# Alabama                                                  96.0
# Alaska                                                   90.0
# Arizona                                                  84.0
# Arkansas                                                 94.0
# California                                               91.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents  \
# State
# Alabama                                                  80.0
# Alaska                                                   94.0
# Arizona                                                  96.0
# Arkansas                                                 95.0
# California                                               89.0
#
#             Car Insurance Premiums ($)  \
# State
# Alabama                         784.55
# Alaska                         1053.48
# Arizona                         899.47
# Arkansas                        827.34
# California                      878.41
#
#             Losses incurred by insurance companies for collisions per insured driver ($)  \
# State
# Alabama                                                145.08
# Alaska                                                 133.93
# Arizona                                                110.35
# Arkansas                                               142.39
# California                                             165.63
#
#             stolen_cars_per_100k
# State
# Alabama                    256.5
# Alaska                     357.7
# Arizona                    249.4
# Arkansas                   245.9
# California                 358.8

# %% [markdown]
# <h1>Mapping Insurance Prices by State</h1>

# %%
#getting geojsondata
us_json = requests.get(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/us_states.json"
).json()

# %% [markdown]
# Here we plot the average full coverage insurance price on year 2020

# %%
m = folium.Map(locations = [35.3, -97.6], tiles = "CartoDB positron", zoom_start = 8, min_zoom = 2) #initializing interactive map

#mapping US insurance data - color legend referrs to values in the "full_coverage" column in insurance data
insurance_map = folium.Choropleth(us_json,
                 data = insurance_cost,
                 columns = [insurance_cost.index, "full_coverage"],
                 key_on = "feature.properties.name",
                 fill_color = "YlGnBu",
                 name = "Full Coverage",
                 legend_name = "Full Coverage Insurance Price (USD) in 2020",
                bins = list(range(1000, 9500, 200)),
                 fill_opacity = 0.7).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42a7baf8ce044bcf186242de6934cc64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42a7baf8ce044bcf186242de6934cc64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42a7baf8ce044bcf186242de6934cc64 = L.map(
#                 &quot;map_42a7baf8ce044bcf186242de6934cc64&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     locations: [35.3, -97.6],
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ab18bfbb4d2ce2e18957253cf235b38 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4ab18bfbb4d2ce2e18957253cf235b38.addTo(map_42a7baf8ce044bcf186242de6934cc64);
#
#
#             var choropleth_c50dcce4123f0612ecfad77aa7b7f192 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_ba444aecaf98082d7bd7d55d19e26a85_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;KS&quot;: case &quot;NE&quot;: case &quot;NH&quot;: case &quot;NM&quot;: case &quot;PA&quot;: case &quot;SC&quot;: case &quot;WV&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8b1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AK&quot;: case &quot;IN&quot;: case &quot;IA&quot;: case &quot;NC&quot;: case &quot;VA&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f7fcc9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;GA&quot;: case &quot;NY&quot;: case &quot;OK&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d7efb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;AR&quot;: case &quot;IL&quot;: case &quot;MN&quot;: case &quot;MS&quot;: case &quot;OR&quot;: case &quot;SD&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#e6f5b1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;MA&quot;: case &quot;ND&quot;: case &quot;TN&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f9b9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;CO&quot;: case &quot;NV&quot;: case &quot;NJ&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c8e9b3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;DE&quot;: case &quot;MD&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;TX&quot;: case &quot;UT&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dff2b2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;FL&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bce4b5&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;ME&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fbfdd1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;OH&quot;: case &quot;VT&quot;: case &quot;WA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f4fac1&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;KY&quot;: case &quot;LA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#aedfb6&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;MI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#192a7b&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#92d4b9&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opa

# %% [markdown]
# <h1>Visualizing Correlation between Independent Variables and State Average Insurance Prices</h1>

# %% [markdown]
# <h2>Part 1: Variables from the Bad Drivers Dataset</h2>

# %%
plotting_data.head()
# Out:
#                  state rank  full_coverage  minimum_coverage  difference  \
# State
# Alabama        Alabama   31         2078.0             736.0      1342.0
# Alaska          Alaska   45         1502.0             485.0      1016.0
# Arizona        Arizona   11         2699.0             980.0      1719.0
# Arkansas      Arkansas   24         2213.0             677.0      1536.0
# California  California   39         1804.0             574.0      1230.0
#
#             Number of drivers involved in fatal collisions per billion miles  \
# State
# Alabama                                                  18.8
# Alaska                                                   18.1
# Arizona                                                  18.6
# Arkansas                                                 22.4
# California                                               12.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# State
# Alabama                                                  39.0
# Alaska                                                   41.0
# Arizona                                                  35.0
# Arkansas                                                 18.0
# California                                               35.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# State
# Alabama                                                  30.0
# Alaska                                                   25.0
# Arizona                                                  28.0
# Arkansas                                                 26.0
# California                                               28.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted  \
# State
# Alabama                                                  96.0
# Alaska                                                   90.0
# Arizona                                                  84.0
# Arkansas                                                 94.0
# California                                               91.0
#
#             Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents  \
# State
# Alabama                                                  80.0
# Alaska                                                   94.0
# Arizona                                                  96.0
# Arkansas                                                 95.0
# California                                               89.0
#
#             Car Insurance Premiums ($)  \
# State
# Alabama                         784.55
# Alaska                         1053.48
# Arizona                         899.47
# Arkansas                        827.34
# California                      878.41
#
#             Losses incurred by insurance companies for collisions per insured driver ($)  \
# State
# Alabama                                                145.08
# Alaska                                                 133.93
# Arizona                                                110.35
# Arkansas                                               142.39
# California                                             165.63
#
#             stolen_cars_per_100k
# State
# Alabama                    256.5
# Alaska                     357.7
# Arizona                    249.4
# Arkansas                   245.9
# California                 358.8

# %%
x1 = plotting_data['Number of drivers involved in fatal collisions per billion miles']
y = plotting_data['full_coverage']

fig1, ax1 = plt.subplots()

# Plot the data as a scatter plot
ax1.scatter(x1, y)

# Set the title and labels
ax1.set_title('Car Insurance Premiums V.S Number of drivers involved in fatal collisions per billion miles')
ax1.set_xlabel('number of drivers involved in fatal collisions')
ax1.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()



x2 = plotting_data['Number of drivers involved in fatal collisions per billion miles']


fig2, ax2 = plt.subplots()

# Plot the data as a scatter plot
ax2.scatter(x2, y)

# Set the title and labels
ax2.set_title('Car Insurance Premiums V.S Number of drivers involved in fatal collisions per billion mileage')
ax2.set_xlabel('Number of drivers involved in fatal collisions per billion mileage')
ax2.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()






x3 = plotting_data['Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding']

fig3, ax3 = plt.subplots()

# Plot the data as a scatter plot
ax3.scatter(x3, y)

# Set the title and labelsPercentage Of Drivers Involved In Fatal Collisions Who Were Speeding
ax3.set_title('Car Insurance Premiums V.S Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding')
ax3.set_xlabel('Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding')
ax3.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()





x4 = plotting_data['Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired']


fig4, ax4 = plt.subplots()

# Plot the data as a scatter plot
ax4.scatter(x4, y)

# Set the title and labels
ax4.set_title('Car Insurance Premiums V.S Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired')
ax4.set_xlabel('Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired')
ax4.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()



x5 = plotting_data['Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted']


fig5, ax5 = plt.subplots()

# Plot the data as a scatter plot
ax5.scatter(x5, y)

# Set the title and labels
ax5.set_title('Car Insurance Premiums V.S Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted')
ax5.set_xlabel('Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted')
ax5.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()



x6 = plotting_data['Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents']


fig6, ax6 = plt.subplots()

# Plot the data as a scatter plot
ax6.scatter(x6, y)

# Set the title and labels
ax6.set_title('Car Insurance Premiums V.S Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents')
ax6.set_xlabel('Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents')
ax6.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()

x7 = plotting_data['stolen_cars_per_100k']


fig7, ax7 = plt.subplots()

# Plot the data as a scatter plot
ax7.scatter(x7, y)

# Set the title and labels
ax7.set_title('Car Insurance Premiums V.S Stolen Cars per 100,000 Population')
ax7.set_xlabel('Stolen Cars per 100,000 people')
ax7.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()

# %% [markdown]
# <h1>Frequency and Severity Analysis</h1>

# %% [markdown]
# Frequency is a measure of the rate at which claims occur and is normally calculated as
# $$
# \text{Frequency} = \frac{{\text{Number of Claims}}}{{\text{Number of Exposure}}}
# $$
# where Exposure is the basic unit of risk that underlies the insurance premium. <br>Now we assume each registered vehicle with exposure being 1, and count the number of accidents happened as number of claims to calculate the frequency. <br>With higher Frequency, we expect the state is more likely to have car accidents and therefore a higher premium.
# Similarly, with higher level of Severity, we expect the accidents cost insurance company more therefore a higher premium.

# %% [markdown]
# - Merge data from various datasets to compute a data frame with Severity, Frequency and Premium

# %%
# Count number of accident happened in each state
acc_count = us_acc_2020['State'].value_counts()
acc_count_df = acc_count.reset_index()

# Add col names
acc_count_df.columns = ['State', 'counts']

# Add col avg severity
acc_count_df['avg_severity'] = us_acc_2020.groupby('State')['Severity'].mean().reset_index()['Severity']

# Join the dataset with states' full name
acc_counts = pd.merge(acc_count_df, state_abb, on='State', how='left')

# Drop abbreviation state name col
acc_counts = acc_counts.drop('State', axis=1)

# Rename the 'State_full' column to 'State' 
acc_counts = acc_counts.rename(columns={'State_full': 'State'})

# Join the datasets registered vehicle
acc_counts = pd.merge(acc_counts, registered_veh, on='State', how='left')

# Calculate frequencies of accident
acc_counts['%Frequency'] = acc_counts['counts']/acc_counts['2020'] * 100

# Join datasets with premium information
acc_counts = acc_counts.rename(columns={'State': 'state'})
acc_counts = pd.merge(acc_counts, insurance_cost, on='state', how = 'left')

# Select wanted cols
acc_counts = acc_counts[['state', 'avg_severity', '%Frequency', 'full_coverage', 'minimum_coverage']].dropna().set_index("state")

# Drop col 2015, and %
acc_counts.head()
# Out:
#                 avg_severity  %Frequency  full_coverage  minimum_coverage
# state
# California          2.216596    0.939304         1804.0             574.0
# Florida             2.209061    0.706014         3370.0            2565.0
# Texas               1.898053    0.327786         2594.0             890.0
# South Carolina      2.088393    1.376560         2013.0             854.0
# New York            2.501764    0.430959         2752.0            1323.0

# %% [markdown]
# - Make Scatter plots

# %%
x8 = acc_counts['avg_severity']
y = acc_counts['full_coverage']

fig8, ax8 = plt.subplots()

# Plot the data as a scatter plot
ax8.scatter(x8, y)

# Set the title and labels
ax8.set_title('Car Insurance Premiums V.S Average Severity')
ax8.set_xlabel('Avg Severity')
ax8.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()

x9 = acc_counts['%Frequency']
y = acc_counts['full_coverage']

fig9, ax9 = plt.subplots()

# Plot the data as a scatter plot
ax9.scatter(x9, y)

# Set the title and labels
ax9.set_title('Car Insurance Premiums V.S Frequency of Accident')
ax9.set_xlabel('Frequency')
ax9.set_ylabel('average full coverage insurance price')

# Show the plot
plt.show()

# %% [markdown]
# There is no obvious correlation between Premium and avg Severity.But we can see a slight positive linear relationship between Premium and Frequency.

# %% [markdown]
# <h1>Regression Analysis</h1>

# %% [markdown]
# <h3>Part 1: Regressing on full coverage insurance price vs minimum coverage regression price</h3>

# %% [markdown]
# We begin by using the identified variables in predicting average full coverage insurance prices

# %% [markdown]
# We implement a log-linear model, which makes it such that a unit change in the independent variable corresponds to a (coefficient * 100)% change in the prices of insurance.

# %%
from sklearn import linear_model
#In the plotting section, we defined y to be the averagefull insurance coverage price

#selecting regressor variables
variables = plotting_data.iloc[:,5:].drop("Car Insurance Premiums ($)", axis = 1)

X = variables.merge(acc_counts, how = "right", left_index = True, right_index = True).drop(columns = ["full_coverage", "minimum_coverage",
                                                    "Losses incurred by insurance companies for collisions per insured driver ($)"])

y = acc_counts["full_coverage"]

X.head()
# Out:
#                 Number of drivers involved in fatal collisions per billion miles  \
# state
# California                                                   12.0
# Florida                                                      17.9
# Texas                                                        19.4
# South Carolina                                               23.9
# New York                                                     12.3
#
#                 Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# state
# California                                                   35.0
# Florida                                                      21.0
# Texas                                                        40.0
# South Carolina                                               38.0
# New York                                                     32.0
#
#                 Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# state
# California                                                   28.0
# Florida                                                      29.0
# Texas                                                        38.0
# South Carolina                                               41.0
# New York                                                     29.0
#
#                 Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted  \
# state
# California                                                   91.0
# Florida                                                      92.0
# Texas                                                        91.0
# South Carolina                                               96.0
# New York                                                     88.0
#
#                 Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents  \
# state
# California                                                   89.0
# Florida                                                      94.0
# Texas                                                        87.0
# South Carolina                                               81.0
# New York                                                     80.0
#
#                 stolen_cars_per_100k  avg_severity  %Frequency
# state
# California                     358.8      2.216596    0.939304
# Florida                        181.8      2.209061    0.706014
# Texas                          267.2      1.898053    0.327786
# South Carolina                 290.8      2.088393    1.376560
# New York                        65.3      2.501764    0.430959

# %%
#defining model
lm = linear_model.LinearRegression()
y1 = np.log(y)
#fitting model
lm.fit(X, y1)
# Out:
# LinearRegression()

# %%
#plotting predictions against real values:
y_pred = lm.predict(X)

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y, y_pred, color='blue')
plt.xlabel('Actual Average Full Coverage Price (USD) ')
plt.ylabel('Predicted Average Full Coverage Price (USD)')
plt.title('Actual vs Average Full Coverage Price (USD)')
plt.grid(True)
plt.show()

# %%
#storing coefficient prices for later
full_price_coef = lm.coef_ 
full_price_coef
# Out:
# array([-0.00018555, -0.00093788, -0.00315266,  0.00076747, -0.00584526,
#         0.00075532,  0.08253723,  0.00771056])

# %% [markdown]
# Next, we run the same regression on minimum coverage prices to see if the independent variables are more effective or less effective in predicting them, as well as if the magnitude of the coefficients change.
# Our hypothesis is that since minimum insurance coverage entails less risk for insurance companies, the aggregate data we have will not be as effective in predicting it, similarly the magnitude of the variable coefficients will not be as large.

# %%
y2 = np.log(acc_counts["minimum_coverage"])
#defining model
lm2 = linear_model.LinearRegression()
#fitting model
lm2.fit(X, y2)
# Out:
# LinearRegression()

# %%
#Plotting predicted values against actual values:
y_pred2 = lm2.predict(X)

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y2, y_pred2, color='blue')
plt.xlabel('Actual Average Minimum Coverage Price (USD) ')
plt.ylabel('Predicted Average Minimum Coverage Price (USD)')
plt.title('Actual vs Average Minimum Coverage Price (USD)')
plt.grid(True)
plt.show()

# %%
minimum_price_coef = lm2.coef_ #saving coefficients for later use
minimum_price_coef
# Out:
# array([-1.69565810e-02, -1.68800268e-03, -9.34437256e-03,  3.86464278e-04,
#        -3.50144733e-03,  4.12285754e-04, -5.93955405e-02,  4.35201994e-01])

# %% [markdown]
# <h3>Part 2: Regression with no outliers</h3>

# %% [markdown]
# It is observed that Michigan's full coverage & minimum coverage prices are more than 2 times higher than the prices of the second ranking state (Rhode Island). The existence of outliers may skew the coefficients of the linear regression. The following regression model will run on the dataset without Michigan to observe the coefficients without the presence of the outlier.

# %%
#regression on full coverage price - drop outlier
y3 = np.log(acc_counts["full_coverage"].drop("Michigan"))
X1 = X.drop("Michigan")

#defining model
lm3 = linear_model.LinearRegression()
#fitting model
lm3.fit(X1, y3)
# Out:
# LinearRegression()

# %%
full_price_coef2 = lm3.coef_ #saving coefficients for later use
full_price_coef2
# Out:
# array([ 2.88850108e-03,  1.10900856e-03,  1.27349484e-03, -5.47035009e-05,
#         2.93852488e-03,  5.83558836e-04, -4.48933761e-03,  6.25209272e-02])

# %%
#Plotting predicted values against actual values - no outlier:
y_pred3 = lm3.predict(X1)

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y3, y_pred3, color='blue')
plt.xlabel('Actual Average Full Coverage Price (USD) ')
plt.ylabel('Predicted Average Full Coverage Price (USD)')
plt.title('Actual vs Average Full Coverage Price (USD), No Outlier')
plt.grid(True)
plt.show()

# %%
#linear regression model on Minimum-coverage insurance - no outlier
y4 = np.log(acc_counts["minimum_coverage"].drop("Michigan"))


#defining model
lm4 = linear_model.LinearRegression()
#fitting model
lm4.fit(X1, y4)
# Out:
# LinearRegression()

# %%
minimum_price_coef2 = lm4.coef_ #saving coefficients for later use
minimum_price_coef2
# Out:
# array([-1.25448393e-02,  1.24959716e-03, -2.99214633e-03, -7.93478997e-04,
#         9.10466413e-03,  1.65774652e-04, -1.84292293e-01,  5.13863456e-01])

# %%
#Plotting predicted values against actual values - no outlier:
y_pred4 = lm4.predict(X1)

# Plotting the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y4, y_pred4, color='blue')
plt.xlabel('Actual Average Minimum Coverage Price (USD) ')
plt.ylabel('Predicted Average Minimum Coverage Price (USD)')
plt.title('Actual vs Average Minimum Coverage Price (USD), No Outlier')
plt.grid(True)
plt.show()

# %% [markdown]
# <h3>Part 3: Comparing results</h3>

# %%
# #construct summary table:
# #list of independent variable names:
var_names = list(X)
var_names
# Out:
# ['Number of drivers involved in fatal collisions per billion miles',
#  'Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding',
#  'Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired',
#  'Percentage Of Drivers Involved In Fatal Collisions Who Were Not Distracted',
#  'Percentage Of Drivers Involved In Fatal Collisions Who Had Not Been Involved In Any Previous Accidents',
#  'stolen_cars_per_100k',
#  'avg_severity',
#  '%Frequency']

# %%
full_coefs = pd.Series(dict(zip(list(X), full_price_coef))) #variable coefficients for regression on full price - with outlier
minimum_coefs = pd.Series(dict(zip(list(X), minimum_price_coef))) #variable coefficients for regression on minimum price - with outlier
full_coefs_no_outlier = pd.Series(dict(zip(list(X), full_price_coef2)))#variable coefficients for regression on full price - no outlier
minimum_coefs_no_outlier = pd.Series(dict(zip(list(X), minimum_price_coef2)))#variable coefficients for regression on minimum price - no outlier

# %%
#variable coefficients for regression on minimum price - with outlier

# %%
summary_table = pd.DataFrame(dict(full_price = full_coefs, min_price = minimum_coefs, 
                                 full_price_no_outliers = full_coefs_no_outlier, min_price_no_outliers = minimum_coefs_no_outlier))

summary_table
# Out:
#                                                     full_price  min_price  \
# Number of drivers involved in fatal collisions ...   -0.000186  -0.016957
# Percentage Of Drivers Involved In Fatal Collisi...   -0.000938  -0.001688
# Percentage Of Drivers Involved In Fatal Collisi...   -0.003153  -0.009344
# Percentage Of Drivers Involved In Fatal Collisi...    0.000767   0.000386
# Percentage Of Drivers Involved In Fatal Collisi...   -0.005845  -0.003501
# stolen_cars_per_100k                                  0.000755   0.000412
# avg_severity                                          0.082537  -0.059396
# %Frequency                                            0.007711   0.435202
#
#                                                     full_price_no_outliers  \
# Number of drivers involved in fatal collisions ...                0.002889
# Percentage Of Drivers Involved In Fatal Collisi...                0.001109
# Percentage Of Drivers Involved In Fatal Collisi...                0.001273
# Percentage Of Drivers Involved In Fatal Collisi...               -0.000055
# Percentage Of Drivers Involved In Fatal Collisi...                0.002939
# stolen_cars_per_100k                                              0.000584
# avg_severity                                                     -0.004489
# %Frequency                                                        0.062521
#
#                                                     min_price_no_outliers
# Number of drivers involved in fatal collisions ...              -0.012545
# Percentage Of Drivers Involved In Fatal Collisi...               0.001250
# Percentage Of Drivers Involved In Fatal Collisi...              -0.002992
# Percentage Of Drivers Involved In Fatal Collisi...              -0.000793
# Percentage Of Drivers Involved In Fatal Collisi...               0.009105
# stolen_cars_per_100k                                             0.000166
# avg_severity                                                    -0.184292
# %Frequency                                                       0.513863

# %%
from sklearn import metrics
#construct mse table to examine goodness of fit in different models
mse_list = [metrics.mean_squared_error(y1, y_pred), metrics.mean_squared_error(y2, y_pred2),
            metrics.mean_squared_error(y3, y_pred3), metrics.mean_squared_error(y4, y_pred4)]

model_list = ["full_price", "min_price", "full_price_no_outliers", "min_price_no_outliers"]

#construct summary table

mse_table = pd.Series(dict(zip(model_list, mse_list)))

print("MSE in different models:")
print(mse_table)
# Out:
# MSE in different models:
# full_price                0.097997
# min_price                 0.207543
# full_price_no_outliers    0.060297
# min_price_no_outliers     0.130019
# dtype: float64

# %% [markdown]
# <h1>Conclusion</h1>

# %% [markdown]
# From the summary tables we can conclude the following:
#
#
#     - The aggregate variables we examined have a larger MSE when regressed on minimum insurance coverage price, which means that the independent variables we identified are better at predicting full coverage prices than minimum coverage prices. This may be due to the fact that less risk is incurred by minimum coverage plans, such that firms have less imperative to set minimum coverage prices in a way that accounts for the variables we examined.
#
#
#     - Coefficients on variables such as cases of stolen cars per 100k people are consistently smaller when regressed on minimum coverage prices, this makes sense because minimum coverage insurances do not cover losses due to theft, thus the firms are less effected by cases of theft when setting prices for minimum coverage insurance.
#
#
#     - Multiple coefficients, such as number of drivers involved in fatal collisions, percent of speeding drivers involved in fatal collisions and percent of alcohol impaired drivers involved in fatal collisions are negative and turns positive after the outlier has been removed.

# %% [markdown]
# <h1>References</h1>

# %% [markdown]
# **DATASETS USED:**
#
#
# Bad Drivers Dataset
# https://www.kaggle.com/datasets/fivethirtyeight/fivethirtyeight-bad-drivers-dataset
#
# US Car Accident Dataset:
# https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
#
# US Crime Data
# https://corgis-edu.github.io/corgis/csv/state_crime/
#
# Car insurance by state (2020):
# https://www.kaggle.com/datasets/andrewmvd/car-insurance-costs
#
# US Accidents Data:
# 'https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
#
# Car Ownership Statistic:
# https://www.valuepenguin.com/auto-insurance/car-ownership-statistics
#
# US state names Codes and Abbreviations：
# https://www.kaggle.com/datasets/francescopettini/us-state-names-codes-and-abbreviations
